# %%
import MySQLdb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# 폰트 설정
mpl.rc('font', family='New Gulim')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %%
conn = MySQLdb.connect(user='root',passwd='jimkwon95',host='localhost',db='toty_db')
cursor = conn.cursor()

cursor.execute("select * from forward")
FW = cursor.fetchall()
conn.close()

# %%
columns = ['이름','출전','득점','도움','유효 슈팅','일반 슈팅','패스 성공 횟수','전체 패스 횟수','드리블 성공 횟수','전체 드리블 횟수',
           '공중볼 경합 성공 횟수','전체 공중볼 경합 횟수','가로채기','태클 성공 횟수','전체 태클 횟수','차단 성공 횟수',
           '전체 차단 횟수','선방(골 차단)','패스 성공률','드리블 성공률','공중볼 경합 성공률','태클 성공률','차단 성공률',
          '전체 슈팅','경기 당 골 횟수','경기 당 도움 횟수','경기 당 슈팅 횟수','경기 당 패스 횟수','경기 당 드리블 횟수',
          '경기 당 공중볼 경합 횟수','경기 당 가로채기 횟수','경기 당 태클 횟수','경기 당 차단 횟수','경기 당 클리어링 횟수']

df_forward = pd.DataFrame(FW,columns=columns)

# %%
print(df_forward['득점'].values.tolist())
# Out:
# [182, 13135, 2, 174, 1069, 688, 544, 169, 664, 1591, 42, 1610, 45, 112, 2631, 41, 4746, 15490, 908, 991, 170, 113, 23, 37, 296, 162, 16455, 52, 3505, 1860, 556, 5167]

# %%
conn = MySQLdb.connect(user='root',passwd='jimkwon95',host='localhost',db='toty_db')
cursor = conn.cursor()

cursor.execute("select * from midfielder")
MF = cursor.fetchall()
conn.close()

# %%
df_midfielder = pd.DataFrame(MF,columns=columns)
df_midfielder
# Out:
#               이름     출전    득점    도움  유효 슈팅  일반 슈팅  패스 성공 횟수  전체 패스 횟수  \
# 0        A. 추아메니    968    61    79    156     76      9221      9698
# 1       E. 페르난데스    307    47    53    102     42      4278      4529
# 2         J. 벨링엄   2229   371   423    763    284     26295     27577
# 3       M. 브로조비치   1846   310   331    606    242     20777     22101
# 4   S. 밀린코비치-사비치    355    72    69    123     54      4375      4580
# 5         나빌 페키르    201    58    51    116     39      1929      2183
# 6        니콜로 바렐라    850   186   159    322    121      9421     10213
# 7        데클런 라이스   2331   113   142    269    151     21438     22523
# 8            로드리   3384   229   341    559    237     33604     35477
# 9      로렌초 펠레그리니      5     0     0      4      3        76        85
# 10       루카 모드리치   9123  2111  1875   4013   1407    109911    117921
# 11      마르틴 외데고르     18     4     4     12      2       285       311
# 12           메리노     35     5     6     10      4       358       370
# 13      베르나르두 실바    780   173   203    348     99      8808      9659
# 14     브루누 페르난데스   1481   426   406    928    302     18743     20593
# 15       산드로 토날리   1008   167   204    337    120     11596     12610
# 16        세코 포파나     23     1     2      7      2       254       265
# 17      소피안 암라바트     24    10     8     15      5       310       332
# 18     스테번 베르하위스    271    86    87    154     36      2511      2937
# 19      아드리앙 라비오   2772   360   430    756    290     29973     31642
# 20       요주아 키미히  18122  1179  2707   2471   1051    157490    176650
# 21       이반 페리시치  22148  7345  6142  14080   4157    221980    241147
# 22          카제미루   6029   442   603   1031    523     56803     60070
# 23      케빈 더브라위너  11579  3851  2950   7268   2235    138484    151997
# 24        토니 크로스  26374  6228  5404  12092   4394    320197    351428
# 25           파레호    318    68    65    132     51      4030      4351
# 26     페데리코 발베르데  10116  1893  1776   3801   1679    114646    120444
# 27           페드리    230    43    55     94     22      3322      3524
# 28      필리프 코스티치    392    34    61     89     32      2960      3259
#
#     드리블 성공 횟수  전체 드리블 횟수  ...  경기 당 골 횟수  경기 당 도움 횟수  경기 당 슈팅 횟수  경기 당 패스 횟수  \
# 0        7728       8288  ...   0.063017    0.081612    0.239669    10.01860
# 1        3359       3566  ...   0.153094    0.172638    0.469055    14.75240
# 2       22449      24438  ...   0.166442    0.189771    0.469717    12.37190
# 3       17627      19151  ...   0.167931    0.179307    0.459372    11.97240
# 4        3624       3915  ...   0.202817    0.194366    0.498592    12.90140
# 5        1786       2009  ...   0.288557    0.253731    0.771144    10.86070
# 6        8510       9346  ...   0.218824    0.187059    0.521176    12.01530
# 7       18002      19044  ...   0.048477    0.060918    0.180180     9.66238
# 8       27314      29056  ...   0.067671    0.100768    0.235225    10.48370
# 9          70         75  ...   0.000000    0.000000    1.400000    17.00000
# 10      95719     104534  ...   0.231393    0.205525    0.594103    12.92570
# 11        224        240  ...   0.222222    0.222222    0.777778    17.27780
# 12        307        334  ...   0.142857    0.171429    0.400000    10.57140
# 13       7752       8599  ...   0.221795    0.260256    0.573077    12.38330
# 14      15860      17415  ...   0.287643    0.274139    0.830520    13.90480
# 15       9836      10761  ...   0.165675    0.202381    0.453373    12.50990
# 16        224        250  ...   0.043478    0.086957    0.391304    11.52170
# 17        262        287  ...   0.416667    0.333333    0.833333    13.83330
# 18       2361       2696  ...   0.317343    0.321033    0.701107    10.83760
# 19      25309      27446  ...   0.129870    0.155123    0.377345    11.41490
# 20     139363     154754  ...   0.065059    0.149376    0.194349     9.74782
# 21     198503     223791  ...   0.331633    0.277316    0.823415    10.88800
# 22      47678      51329  ...   0.073312    0.100017    0.257754     9.96351
# 23     119776     131356  ...   0.332585    0.254772    0.820710    13.12700
# 24     280172     305206  ...   0.236142    0.204899    0.625085    13.32480
# 25       3446       3733  ...   0.213836    0.204403    0.575472    13.68240
# 26     101550     110856  ...   0.187129    0.175563    0.541716    11.90630
# 27       2500       2682  ...   0.186957    0.239130    0.504348    15.32170
# 28       2731       3063  ...   0.086735    0.155612    0.308673     8.31378
#
#     경기 당 드리블 횟수  경기 당 공중볼 경합 횟수  경기 당 가로채기 횟수  경기 당 태클 횟수  경기 당 차단 횟수  \
# 0       8.56198        0.990702      0.702479    0.908058    0.866736
# 1      11.61560        0.684039      0.671010    1.241040    0.664495
# 2      10.96370        0.963661      0.760879    1.079410    0.693136
# 3      10.37430        0.931203      0.760563    1.158720    0.770856
# 4      11.02820        0.971831      0.785915    1.146480    0.647887
# 5       9.99502        0.850746      0.328358    0.537313    0.169154
# 6      10.99530        0.883529      0.684706    0.985882    0.688235
# 7       8.16988        0.890176      0.674818    0.861862    0.968683
# 8       8.58629        0.823582      0.739953    0.994976    0.964243
# 9      15.00000        0.400000      0.400000    0.800000    0.400000
# 10     11.45830        0.914831      0.617670    0.939603    0.530198
# 11     13.33330        0.277778      0.555556    1.333330    0.611111
# 12      9.54286        1.285710      0.828571    0.971429    0.485714
# 13     11.02440        0.682051      0.517949    0.830769    0.512821
# 14     11.75890        1.062120      0.508440    0.813639    0.433491
# 15     10.67560        1.066470      0.710317    1.054560    0.830357
# 16     10.86960        1.000000      0.782609    0.913043    1.043480
# 17     11.95830        0.916667      0.875000    1.250000    0.625000
# 18      9.94834        0.992620      0.350554    0.590406    0.184502
# 19      9.90115        0.870851      0.773088    1.089830    0.817821
# 20      8.53957        0.562907      0.755049    0.994647    0.818453
# 21     10.10430        1.013140      0.409879    0.661324    0.227470
# 22      8.51368        0.889866      0.741085    0.959529    0.949079
# 23     11.34430        0.985405      0.507384    0.806719    0.412644
# 24     11.57220        1.041180      0.686927    0.976909    0.585804
# 25     11.73900        1.238990      0.742138    1.132080    0.644654
# 26     10.95850        1.019970      0.705022    0.970344    0.637802
# 27     11.66090        0.478261      0.569565    1.043480    0.721739
# 28      7.81378        0.571429      0.688776    0.903061    0.678571
#
#     경기 당 클리어링 횟수
# 0       0.302686
# 1       0.094463
# 2       0.226559
# 3       0.228602
# 4       0.194366
# 5       0.084577
# 6       0.160000
# 7       0.338052
# 8       0.288121
# 9       0.000000
# 10      0.170448
# 11      0.055556
# 12      0.257143
# 13      0.120513
# 14      0.145847
# 15      0.268849
# 16      0.434783
# 17      0.041667
# 18      0.099631
# 19      0.258297
# 20      0.272542
# 21      0.123713
# 22      0.331067
# 23      0.154763
# 24      0.225032
# 25      0.198113
# 26      0.224199
# 27      0.039130
# 28      0.250000
#
# [29 rows x 34 columns]

# %%
conn = MySQLdb.connect(user='root',passwd='jimkwon95',host='localhost',db='toty_db')
cursor = conn.cursor()

cursor.execute("select * from defender")
DF = cursor.fetchall()
conn.close()

# %%
df_defender = pd.DataFrame(DF,columns=columns)
df_defender
# Out:
#            이름     출전    득점    도움  유효 슈팅  일반 슈팅  패스 성공 횟수  전체 패스 횟수  드리블 성공 횟수  \
# 0      C. 비라기     12     1     0      2      0       110       122         91
# 1    J. 그바르디올    998    60    96    156     76      7371      7882       6213
# 2        그리말도    484    20    64     43     17      3503      3907       3175
# 3   니콜라스 오타멘디     94     2     2      5      4       745       779        627
# 4     니클라스 쥘레    959    24    43     57     48      7208      7524       6037
# 5    다요 우파메카노   7939   141   320    478    321     60108     62942      50234
# 6      리스 제임스  29775  1390  3649   3374   1717    226913    246066     205946
# 7    마르코스 아쿠냐    291    21    40     41     17      2073      2271       1871
# 8       마르키뉴스   1954    64   125    179    121     13686     14517      11408
# 9     버질 반데이크   7091   264   452    835    537     51211     54331      42604
# 10       브레메르   1367    31    76    120     73      9898     10398       8196
# 11   아슈라프 하키미  14897   648  1895   1580    747    111985    121267     101104
# 12   알폰소 데이비스  16175   747  1957   1595    760    118969    128553     108074
# 13    에데르 밀리탕  27511   817  1699   2522   1651    217378    229321     185500
# 14    제레미 프림퐁   1850    65   221    171     84     14017     15212      12857
# 15    조나탕 클로스      7     0     1      0      2        46        49         45
# 16     주앙 칸셀루   9935   962  1312   1976    795     86900     93625      75789
# 17       쥘 쿤데    545    17    33     44     34      3840      4079       3186
# 18   칼리두 쿨리발리    336     5    15     24     16      2433      2551       1962
# 19  크리스티안 로메로   4761   112   248    373    254     34208     36146      27806
# 20   키어런 트리피어   2058   137   293    301    150     16583     18363      14965
# 21   테오 에르난데스  14089   653  1525   1516    735    104078    112472      91603
# 22     티아구 실바   6650   201   331    501    275     50680     53317      42890
# 23    피카요 토모리  15367   443  1123   1386    952    115686    122753      94470
# 24     후벵 디아스   3234   123   191    327    188     22207     23542      18232
#
#     전체 드리블 횟수  ...  경기 당 골 횟수  경기 당 도움 횟수  경기 당 슈팅 횟수  경기 당 패스 횟수  \
# 0          93  ...   0.083333    0.000000    0.166667    10.16670
# 1        6867  ...   0.060120    0.096192    0.232465     7.89780
# 2        3584  ...   0.041322    0.132231    0.123967     8.07231
# 3         655  ...   0.021277    0.021277    0.095745     8.28723
# 4        6410  ...   0.025026    0.044838    0.109489     7.84567
# 5       53146  ...   0.017760    0.040307    0.100642     7.92820
# 6      230063  ...   0.046684    0.122552    0.170982     8.26418
# 7        2089  ...   0.072165    0.137457    0.199313     7.80412
# 8       12364  ...   0.032753    0.063971    0.153531     7.42938
# 9       46151  ...   0.037230    0.063743    0.193485     7.66197
# 10       8821  ...   0.022677    0.055596    0.141185     7.60644
# 11     113780  ...   0.043499    0.127207    0.156206     8.14036
# 12     122096  ...   0.046182    0.120989    0.145595     7.94764
# 13     198328  ...   0.029697    0.061757    0.151685     8.33561
# 14      14546  ...   0.035135    0.119459    0.137838     8.22270
# 15         51  ...   0.000000    0.142857    0.285714     7.00000
# 16      83910  ...   0.096829    0.132058    0.278913     9.42375
# 17       3464  ...   0.031193    0.060551    0.143119     7.48440
# 18       2113  ...   0.014881    0.044643    0.119048     7.59226
# 19      29805  ...   0.023525    0.052090    0.131695     7.59210
# 20      16730  ...   0.066570    0.142371    0.219145     8.92274
# 21     102139  ...   0.046348    0.108240    0.159770     7.98297
# 22      45651  ...   0.030226    0.049774    0.116692     8.01759
# 23     102082  ...   0.028828    0.073079    0.152144     7.98809
# 24      19715  ...   0.038033    0.059060    0.159246     7.27953
#
#     경기 당 드리블 횟수  경기 당 공중볼 경합 횟수  경기 당 가로채기 횟수  경기 당 태클 횟수  경기 당 차단 횟수  \
# 0       7.75000        0.583333      0.250000    0.416667    0.916667
# 1       6.88076        0.804609      0.857715    1.040080    1.219440
# 2       7.40496        0.564050      0.861570    1.119830    0.805785
# 3       6.96809        0.702128      0.797872    0.957447    0.882979
# 4       6.68405        0.880083      0.734098    0.806048    1.107400
# 5       6.69429        0.826930      0.690767    0.829827    1.056050
# 6       7.72672        0.530613      0.776893    0.970244    0.904282
# 7       7.17869        0.529210      0.707904    1.013750    0.893471
# 8       6.32753        0.796827      0.864893    1.037870    1.147390
# 9       6.50839        0.939783      0.787336    0.964744    1.114930
# 10      6.45282        0.815655      0.775421    0.929773    1.076810
# 11      7.63778        0.557092      0.780224    1.012620    0.864536
# 12      7.54844        0.653725      0.856383    1.089400    0.891932
# 13      7.20904        0.907492      0.754462    0.881974    1.034130
# 14      7.86270        0.559459      0.827568    1.062700    0.877838
# 15      7.28571        0.428571      0.571429    0.571429    0.857143
# 16      8.44590        0.639658      0.751183    1.021440    0.870458
# 17      6.35596        0.842202      0.809174    1.029360    1.126610
# 18      6.28869        0.845238      0.794643    0.934524    1.104170
# 19      6.26024        0.809914      0.798152    1.030880    1.123500
# 20      8.12925        0.517979      0.789602    1.022840    0.832362
# 21      7.24956        0.670452      0.830577    1.026830    0.942863
# 22      6.86481        0.804662      0.720601    0.861053    1.073380
# 23      6.64294        0.821761      0.790981    0.928353    1.130210
# 24      6.09617        0.818491      0.800247    0.988559    1.161410
#
#     경기 당 클리어링 횟수
# 0       0.000000
# 1       0.340681
# 2       0.318182
# 3       0.308511
# 4       0.358707
# 5       0.331024
# 6       0.317313
# 7       0.250859
# 8       0.339304
# 9       0.364265
# 10      0.330651
# 11      0.298919
# 12      0.324451
# 13      0.382792
# 14      0.318378
# 15      0.285714
# 16      0.276195
# 17      0.280734
# 18      0.330357
# 19      0.316950
# 20      0.250243
# 21      0.340549
# 22      0.338045
# 23      0.372356
# 24      0.303340
#
# [25 rows x 34 columns]

# %%
conn = MySQLdb.connect(user='root',passwd='jimkwon95',host='localhost',db='toty_db')
cursor = conn.cursor()

cursor.execute("select * from goalkeeper")
GK = cursor.fetchall()
conn.close()

# %%
gk_columns = ['이름','출전','득점','도움','유효 슈팅','일반 슈팅','패스 성공 횟수','전체 패스 횟수','드리블 성공 횟수','전체 드리블 횟수',
           '공중볼 경합 성공 횟수','전체 공중볼 경합 횟수','가로채기','태클 성공 횟수','전체 태클 횟수','차단 성공 횟수',
           '전체 차단 횟수','선방(골 차단)','패스 성공률']

df_goalkeeper = pd.DataFrame(GK,columns=gk_columns)

x1 = df_goalkeeper['출전'].values.tolist()
y1 = df_goalkeeper['선방(골 차단)'].values.tolist()
z1 = []

for x,y in zip(x1,y1):
    z = y/x
    z1.append(z)

df_goalkeeper['경기 당 선방 횟수'] = z1

df_goalkeeper
# Out:
#            이름     출전  득점  도움  유효 슈팅  일반 슈팅  패스 성공 횟수  전체 패스 횟수  드리블 성공 횟수  \
# 0    E. 마르티네스    363   0   0      0      0       764       818        112
# 1     그레고르 코벨    656   0   0      0      0      1356      1455        240
# 2      마이크 메냥    690   0   0      0      0      1433      1525        280
# 3  보이치에흐 슈체스니   4923   1   3      1      0     10274     10991       1688
# 4         알리송   3432   0   0      0      0      7116      7708       1435
# 5       야신 부누    105   0   0      0      0       212       227         45
# 6        에데르송    754   0   0      1      1      1655      1757        388
# 7      위고 요리스   1032   0   0      0      0      2246      2404        445
# 8      케빈 트라프     34   0   0      0      0        63        68         15
# 9     티보 쿠르투아  60008   4   6      7      2    126441    135079      25054
#
#    전체 드리블 횟수  공중볼 경합 성공 횟수  전체 공중볼 경합 횟수  가로채기  태클 성공 횟수  전체 태클 횟수  차단 성공 횟수  \
# 0        113             0             0     2         3         5         0
# 1        244             0             1     1         1         2         0
# 2        281             0             0     1         1         1         0
# 3       1718             1             9     5         5        19         0
# 4       1455             0             2     4         4         8         0
# 5         45             0             0     0         0         0         0
# 6        393             0             1     4         4         8         0
# 7        451             1             4     0         1         3         0
# 8         15             0             0     0         0         0         0
# 9      25365            25            86    39        49       121         0
#
#    전체 차단 횟수  선방(골 차단)    패스 성공률  경기 당 선방 횟수
# 0         0       870  0.933985    2.396694
# 1         0      1408  0.931959    2.146341
# 2         0      1416  0.939672    2.052174
# 3         0     11344  0.934765    2.304286
# 4         0      7432  0.923197    2.165501
# 5         0       195  0.933921    1.857143
# 6         0      1579  0.941947    2.094164
# 7         0      2342  0.934276    2.269380
# 8         0        67  0.926471    1.970588
# 9         0    135238  0.936052    2.253666

# %%
title_font = {
    'fontsize':16,
    'fontweight':'heavy'
}

font1 = {'weight': 'bold',
         'size': 14
         }

# %%
# 1-1. 공격력 요인의 가중치

GoalWeight = 0.625
AssistWeight = 0.375

# 1-2. 공격력에 대한 포지션별 가중치
FW_GoalWeight = 0.161
MF_GoalWeight = 0.285
DF_GoalWeight = 0.554
FW_AssistWeight = 0.208
MF_AssistWeight = 0.284
DF_AssistWeight = 0.508

# %%
# 공격력 평점 구하는 법 → (골 기록*골 가중치*포지션별 골 가중치)+(도움 기록*도움 가중치*포지션별 도움 가중치)

FW_goal_per = df_forward['경기 당 골 횟수'].tolist()
FW_assist_per = df_forward['경기 당 도움 횟수'].tolist()

FW_attack = []
for goal,assist in zip(FW_goal_per,FW_assist_per):
    score = (goal*GoalWeight*FW_GoalWeight)+(assist*AssistWeight*FW_AssistWeight)
    FW_attack.append(score*100)
    
MF_goal_per = df_midfielder['경기 당 골 횟수'].tolist()
MF_assist_per = df_midfielder['경기 당 도움 횟수'].tolist()

MF_attack = []
for goal,assist in zip(MF_goal_per,MF_assist_per):
    score = (goal*GoalWeight*MF_GoalWeight)+(assist*AssistWeight*MF_AssistWeight)
    MF_attack.append(score*100)
    
DF_goal_per = df_defender['경기 당 골 횟수'].tolist()
DF_assist_per = df_defender['경기 당 도움 횟수'].tolist()

DF_attack = []
for goal,assist in zip(DF_goal_per,DF_assist_per):
    score = (goal*GoalWeight*DF_GoalWeight)+(assist*AssistWeight*DF_AssistWeight)
    DF_attack.append(score*100)
    
df_forward['공격력']=FW_attack
df_midfielder['공격력']=MF_attack
df_defender['공격력']=DF_attack

# %%
# 2-1 기본능력 요인의 가중치

ShootWeight = 0.348
PassWeight = 0.421
DribbleWeight = 0.231

# 2-2 기본능력에 대한 포지션별 가중치

FW_ShootWeight = 0.129
FW_PassWeight = 0.495
FW_DribbleWeight = 0.542
MF_ShootWeight = 0.277
MF_PassWeight = 0.307
MF_DribbleWeight = 0.296
DF_ShootWeight = 0.594
DF_PassWeight = 0.208
DF_DribbleWeight = 0.162

# %%
# 기본능력 평점 구하는 법 → (슈팅 기록*슈팅 가중치*포지션별 슈팅 가중치)+
#                            (패스 기록*패스 가중치*포지션별 패스 가중치)+
#                            (드리블 기록*드리블 가중치*포지션별 드리블 가중치)

FW_shoot_per = df_forward['경기 당 슈팅 횟수'].tolist()
FW_pass_per = df_forward['경기 당 패스 횟수'].tolist()
FW_dribble_per = df_forward['경기 당 드리블 횟수'].tolist()

FW_ability = []
for shoot,passes,dribble in zip(FW_shoot_per,FW_pass_per,FW_dribble_per):
    score = (shoot*ShootWeight*FW_ShootWeight)+(passes*PassWeight*FW_PassWeight)+(dribble*DribbleWeight*FW_DribbleWeight)
    FW_ability.append(score*100)
    
MF_shoot_per = df_midfielder['경기 당 슈팅 횟수'].tolist()
MF_pass_per = df_midfielder['경기 당 패스 횟수'].tolist()
MF_dribble_per = df_midfielder['경기 당 드리블 횟수'].tolist()

MF_ability = []
for shoot,passes,dribble in zip(MF_shoot_per,MF_pass_per,MF_dribble_per):
    score = (shoot*ShootWeight*MF_ShootWeight)+(passes*PassWeight*MF_PassWeight)+(dribble*DribbleWeight*MF_DribbleWeight)
    MF_ability.append(score*100)
    
DF_shoot_per = df_defender['경기 당 슈팅 횟수'].tolist()
DF_pass_per = df_defender['경기 당 패스 횟수'].tolist()
DF_dribble_per = df_defender['경기 당 드리블 횟수'].tolist()

DF_ability = []
for shoot,passes,dribble in zip(DF_shoot_per,DF_pass_per,DF_dribble_per):
    score = (shoot*ShootWeight*DF_ShootWeight)+(passes*PassWeight*DF_PassWeight)+(dribble*DribbleWeight*DF_DribbleWeight)
    DF_ability.append(score*100)
    
df_forward['기본 능력']=FW_ability
df_midfielder['기본 능력']=MF_ability
df_defender['기본 능력']=DF_ability

# %%
# 3-1 수비력 요인의 가중치

TackleWeight = 0.308
InterceptWeight = 0.311
ClearingWeight = 0.205
BlockWeight = 0.176

# 3-2 수비력에 대한 포지션별 가중치

FW_TackleWeight = 0.459
FW_InterceptWeight = 0.473
FW_ClearingWeight = 0.442
FW_BlockWeight = 0.446
MF_TackleWeight = 0.273
MF_InterceptWeight = 0.328
MF_ClearingWeight = 0.304
MF_BlockWeight = 0.296
DF_TackleWeight = 0.268
DF_InterceptWeight = 0.199
DF_ClearingWeight = 0.254
DF_BlockWeight = 0.258

# %%
# 수비력 평점 구하는 법 → (태클 기록*태클 가중치*포지션별 태클 가중치)+
#                          (인터셉트 기록*인터셉트 가중치*포지션별 인터셉트 가중치)+
#                          (클리어링 기록*클리어링 가중치*포지션별 클리어링 가중치)+
#                          (블락 기록*블락 가중치*포지션별 블락 가중치)

FW_tackle_per = df_forward['경기 당 태클 횟수'].tolist()
FW_intercept_per = df_forward['경기 당 가로채기 횟수'].tolist()
FW_clearing_per = df_forward['경기 당 클리어링 횟수'].tolist()
FW_block_per = df_forward['경기 당 차단 횟수'].tolist()

FW_defense = []
for tackle,intercept,clearing,block in zip(FW_tackle_per,FW_intercept_per,FW_clearing_per,FW_block_per):
    score = (tackle*TackleWeight*FW_ShootWeight)+(intercept*InterceptWeight*FW_InterceptWeight)+(clearing*ClearingWeight*FW_ClearingWeight)+(block*BlockWeight*FW_BlockWeight)
    FW_defense.append(score*100)
    
MF_tackle_per = df_midfielder['경기 당 태클 횟수'].tolist()
MF_intercept_per = df_midfielder['경기 당 가로채기 횟수'].tolist()
MF_clearing_per = df_midfielder['경기 당 클리어링 횟수'].tolist()
MF_block_per = df_midfielder['경기 당 차단 횟수'].tolist()

MF_defense = []
for tackle,intercept,clearing,block in zip(MF_tackle_per,MF_intercept_per,MF_clearing_per,MF_block_per):
    score = (tackle*TackleWeight*MF_ShootWeight)+(intercept*InterceptWeight*MF_InterceptWeight)+(clearing*ClearingWeight*MF_ClearingWeight)+(block*BlockWeight*MF_BlockWeight)
    MF_defense.append(score*100)
    
DF_tackle_per = df_defender['경기 당 태클 횟수'].tolist()
DF_intercept_per = df_defender['경기 당 가로채기 횟수'].tolist()
DF_clearing_per = df_defender['경기 당 클리어링 횟수'].tolist()
DF_block_per = df_defender['경기 당 차단 횟수'].tolist()

DF_defense = []
for tackle,intercept,clearing,block in zip(DF_tackle_per,DF_intercept_per,DF_clearing_per,DF_block_per):
    score = (tackle*TackleWeight*DF_ShootWeight)+(intercept*InterceptWeight*DF_InterceptWeight)+(clearing*ClearingWeight*DF_ClearingWeight)+(block*BlockWeight*DF_BlockWeight)
    DF_defense.append(score*100)
    
df_forward['수비력']=FW_defense
df_midfielder['수비력']=MF_defense
df_defender['수비력']=DF_defense

# %%
# 4-1 기여도 요인의 가중치(공중볼 경합만 반영, 세컨볼 획득에 대한 데이터는 없음)

FW_headerWeight = 0.392
MF_headerWeight = 0.258
DF_headerWeight = 0.351

# %%
# 기여도 요인 평점 구하는 법 → (공중볼 경합 기록*포지션별 공중볼 경합 가중치)

FW_header_per = df_forward['경기 당 공중볼 경합 횟수']
FW_contribution = []
for header in FW_header_per:
    score = header*FW_headerWeight
    FW_contribution.append(score*100)

MF_header_per = df_midfielder['경기 당 공중볼 경합 횟수']
MF_contribution = []
for header in MF_header_per:
    score = header*MF_headerWeight
    MF_contribution.append(score*100)
    
DF_header_per = df_defender['경기 당 공중볼 경합 횟수']
DF_contribution = []
for header in DF_header_per:
    score = header*DF_headerWeight
    DF_contribution.append(score*100)
    
df_forward['기여도']=FW_contribution
df_midfielder['기여도']=MF_contribution
df_defender['기여도']=DF_contribution

# %%
df_forward['총점'] = df_forward['공격력']+df_forward['기본 능력']+df_forward['수비력']+df_forward['기여도']
df_midfielder['총점'] = df_midfielder['공격력']+df_midfielder['기본 능력']+df_midfielder['수비력']+df_midfielder['기여도']
df_defender['총점'] = df_defender['공격력']+df_defender['기본 능력']+df_defender['수비력']+df_defender['기여도']

# %% [markdown]
# ## 포지션별 각 선수 출전시간 분석

# %%
df_forward = df_forward.sort_values('출전',ascending=True)

names = df_forward['이름'].values.tolist()
total_games = df_forward['출전'].values.tolist()
y = np.arange(len(names))

plt.figure(figsize=(10,10))
plt.title('Forward 선수별 출전시간',fontdict=title_font)
plt.barh(y,total_games,color='r',alpha=0.5,label='출전시간(분)')
plt.yticks(y,names)
plt.xlabel('출전시간(분)',fontdict=font1,labelpad=15)
plt.grid(True,axis='x')
plt.legend(loc='lower right')

plt.show()

# %%
df_midfielder = df_midfielder.sort_values('출전',ascending=True)

names = df_midfielder['이름'].values.tolist()
total_games = df_midfielder['출전'].values.tolist()
y = np.arange(len(names))

plt.figure(figsize=(10,10))
plt.title('Midfielder 선수별 출전시간',fontdict=title_font)
plt.barh(y,total_games,color='g',alpha=0.5,label='출전시간(분)')
plt.yticks(y,names)
plt.xlabel('출전시간(분)',fontdict=font1,labelpad=15)
plt.grid(True,axis='x')
plt.legend(loc='lower right')

plt.show()

# %%
df_defender = df_defender.sort_values('출전',ascending=True)

names = df_defender['이름'].values.tolist()
total_games = df_defender['출전'].values.tolist()
y = np.arange(len(names))

plt.figure(figsize=(10,10))
plt.title('Defender 선수별 출전시간',fontdict=title_font)
plt.barh(y,total_games,color='b',alpha=0.5,label='출전시간(분)')
plt.yticks(y,names)
plt.xlabel('출전시간(분)',fontdict=font1,labelpad=15)
plt.grid(True,axis='x')
plt.legend(loc='lower right')

plt.show()

# %%
df_goalkeeper = df_goalkeeper.sort_values('출전',ascending=True)

names = df_goalkeeper['이름'].values.tolist()
total_games = df_goalkeeper['출전'].values.tolist()
y = np.arange(len(names))

plt.figure(figsize=(10,10))
plt.title('Goalkeeper 선수별 출전시간',fontdict=title_font)
plt.barh(y,total_games,color='k',alpha=0.5,label='출전시간(분)')
plt.yticks(y,names)
plt.xlabel('출전시간(분)',fontdict=font1,labelpad=15)
plt.grid(True,axis='x')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ## 포지션별 선수 평점(1000경기 이하 선수들은 제외)

# %%
df_forward = df_forward.sort_values('총점',ascending=True)
df_forward = df_forward[df_forward['출전']>=1000]

names = df_forward['이름'].values.tolist()
total_games = df_forward['총점'].values.tolist()
y = np.arange(len(names))

plt.figure(figsize=(10,10))
plt.title('Forward 선수별 총점',fontdict=title_font)
plt.barh(y,total_games,color='r',alpha=0.5,label='총점')
plt.yticks(y,names)
plt.xlabel('총점',fontdict=font1,labelpad=15)
#plt.xlim([40,60])
plt.grid(True,axis='x')
plt.legend(loc='lower right')

plt.show()

# %%
df_midfielder = df_midfielder.sort_values('총점',ascending=True)
df_midfielder = df_midfielder[df_midfielder['출전']>=1000]

names = df_midfielder['이름'].values.tolist()
total_games = df_midfielder['총점'].values.tolist()
y = np.arange(len(names))

plt.figure(figsize=(10,10))
plt.title('Midfielder 선수별 총점',fontdict=title_font)
plt.barh(y,total_games,color='g',alpha=0.5,label='총점')
plt.yticks(y,names)
plt.xlabel('총점',fontdict=font1,labelpad=15)
plt.grid(True,axis='x')
#plt.xlim([40,60])
plt.legend(loc='lower right')

plt.show()

# %%
df_defender = df_defender.sort_values('총점',ascending=True)
df_defender = df_defender[df_defender['출전']>=1000]

names = df_defender['이름'].values.tolist()
total_games = df_defender['총점'].values.tolist()
y = np.arange(len(names))

plt.figure(figsize=(10,10))
plt.title('Defender 선수별 총점',fontdict=title_font)
plt.barh(y,total_games,color='b',alpha=0.5,label='총점')
plt.yticks(y,names)
plt.xlabel('총점',fontdict=font1,labelpad=15)
plt.grid(True,axis='x')
#plt.xlim([30,50])
plt.legend(loc='lower right')

plt.show()

# %%
# 피온4 데일리차트 홈페이지 접속하기 
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
import chromedriver_autoinstaller
import sys
import os
import re
import requests
import pandas as pd
import numpy as np
import time

chrome_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(chrome_path)
url = 'https://fifaonline4.nexon.com/datacenter/dailysquad'
driver.get(url)
response = requests.get(url)
html = response.text
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20152\2729107051.py:15: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chrome_path)

# %%
best_players = []

move = driver.find_element(By.XPATH,'//*[@id="positionSlider"]/div/span')
time.sleep(3)
for i in range(2,17): # 총 15개의 포지션별 인기 선수를 수집
    positions = []
    position = driver.find_element(By.CSS_SELECTOR,'#middle > div > div > div.daily > div.position_pl.daily_wrap > div.position_pl__cont.content_wrap > div.position_tab > div:nth-child('+str(i)+') > a').text
    time.sleep(4)
    select = driver.find_element(By.CSS_SELECTOR,'#middle > div > div > div.daily > div.position_pl.daily_wrap > div.position_pl__cont.content_wrap > div.position_tab > div:nth-child('+str(i)+') > a').click()
    positions.append(position)
    time.sleep(8)
    top1_SeasonAndName = driver.find_element(By.CSS_SELECTOR,'#divBestUsePositionPlayer > div.item_list.swiper-slide.swiper-slide-active > div > div > div.info > span.name_wrap')
    time.sleep(8)
    top1_divTag = top1_SeasonAndName.find_element(By.CSS_SELECTOR,'span.icon > img')
    time.sleep(8)
    top1_src = top1_divTag.get_attribute('src')
    time.sleep(8)
    top1_regex = re.compile('{}(.*){}'.format(re.escape('season/'), re.escape('.png')))
    top1_text = top1_regex.findall(str(top1_src))
    top1_name = top1_SeasonAndName.text
    top1_season_name = top1_text[0]+' '+top1_name
    positions.append(top1_season_name) # 포지션별 1위는 css 양식이 달라 따로 수집해서 append 하였음
    for j in range(2,10):
        SeasonAndName = driver.find_element(By.CSS_SELECTOR,'#divBestUsePositionPlayer > div:nth-child('+str(j)+') > div > div > div.info > span.name_wrap')
        time.sleep(8)
        divTag = SeasonAndName.find_element(By.CSS_SELECTOR,'span.icon > img')
        time.sleep(8)
        src = divTag.get_attribute('src')
        time.sleep(8)
        regex = re.compile('{}(.*){}'.format(re.escape('season/'), re.escape('.png')))
        text = regex.findall(str(src)) # 선수 시즌 추출(리스트 형식이므로 원소 추출하는 방식으로 데이터 가져와야 됨)
        name = SeasonAndName.text # 선수 이름 추출
        season_name = text[0]+' '+name 
        positions.append(season_name)
        time.sleep(8)
    
    ActionChains(driver).drag_and_drop_by_offset(move,549,0).perform() # 스크롤 오른쪽으로 이동

    for k in range(10,17):
        SeasonAndName = driver.find_element(By.CSS_SELECTOR,'#divBestUsePositionPlayer > div:nth-child('+str(k)+') > div > div > div.info > span.name_wrap')
        time.sleep(5)
        divTag = SeasonAndName.find_element(By.CSS_SELECTOR,'span.icon > img')
        src = divTag.get_attribute('src')
        regex = re.compile('{}(.*){}'.format(re.escape('season/'), re.escape('.png')))
        text = regex.findall(str(src))
        name = SeasonAndName.text
        season_name = text[0]+' '+name
        positions.append(season_name)
        
    best_players.append(positions)
    print('process {0} complete'.format(i-1))
    print(positions)
    print('------------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Input In [3], in <cell line: 5>()
#       7 position = driver.find_element(By.CSS_SELECTOR,'#middle > div > div > div.daily > div.position_pl.daily_wrap > div.position_pl__cont.content_wrap > div.position_tab > div:nth-child('+str(i)+') > a').text
#       8 time.sleep(4)
# ----> 9 select = driver.find_element(By.CSS_SELECTOR,'#middle > div > div > div.daily > div.position_pl.daily_wrap > div.position_pl__cont.content_wrap > div.position_tab > div:nth-child('+str(i)+') > a').click()
#      10 positions.append(position)
#      11 time.sleep(8)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:88, in WebElement.click(self)
#      86 def click(self) -> None:
#      87     """Clicks the element."""
# ---> 88     self._execute(Command.CLICK_ELEMENT)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: element click intercepted: Element <a href="javascript:;" onclick="DailyChart.GetBestUsePositionPlayer(this,25);">...</a> is not clickable at point (263, 688). Other element would receive the click: <a href="https://fifaonline4.nexon.com/news/notice/view?n4ArticleSN=3808" target="_self" class="na_slide" style="animation-duration: 20.6s;">...</a>
#   (Session info: chrome=108.0.5359.99)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00E7E563]
# 	(No symbol) [0x00E07FC1]
# 	(No symbol) [0x00CFD04D]
# 	(No symbol) [0x00D328B9]
# 	(No symbol) [0x00D308CC]
# 	(No symbol) [0x00D2E4CB]
# 	(No symbol) [0x00D2D164]
# 	(No symbol) [0x00D232A6]
# 	(No symbol) [0x00D4858C]
# 	(No symbol) [0x00D22BFF]
# 	(No symbol) [0x00D48804]
# 	(No symbol) [0x00D5C9EB]
# 	(No symbol) [0x00D48386]
# 	(No symbol) [0x00D2163C]
# 	(No symbol) [0x00D2269D]
# 	GetHandleVerifier [0x01119B82+2658722]
# 	GetHandleVerifier [0x0110CB84+2605476]
# 	GetHandleVerifier [0x00F2825A+620666]
# 	GetHandleVerifier [0x00F26E80+615584]
# 	(No symbol) [0x00E105EC]
# 	(No symbol) [0x00E15958]
# 	(No symbol) [0x00E15A45]
# 	(No symbol) [0x00E2050B]
# 	BaseThreadInitThunk [0x75F4FEF9+25]
# 	RtlGetAppContainerNamedObjectPath [0x777E7BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x777E7B8E+238]

# %%
print(best_players)
# Out:
# [['ST', '2012KH 박주영', '22TOTY R. 레반도프스키', '22TOTS 크리스티아누 호날두', '21TOTY 크리스티아누 호날두', 'MC 호나우두', '21TOTY R. 레반도프스키', '22TOTY 손흥민', 'LN 차범근', '2012KH 지동원', '22TOTS 해리 케인', 'MC 크리스티아누 호날두', 'FA 사뮈엘 에토', 'LN 안드리 셰우첸코', '21UCL 사디오 마네', '22TOTS R. 레반도프스키', '21UCL 카이 하베르츠'], ['CF', '2012KH 박주영', '2012KH 지동원', '21UCL 사디오 마네', 'LOL 이반 페리시치', 'LH 차범근', '22TOTY 손흥민', '21UCL 세르주 그나브리', 'TKL 고정운', '21UCL 카이 하베르츠', '21UCL 이반 페리시치', 'BOE21 카림 벤제마', '21UCL 메이슨 마운트', '21UCL 카림 벤제마', '21TOTY 손흥민', 'EBS 에덴 아자르', '22TOTS 필 포든'], ['LW', '21UCL 사디오 마네', 'TKL 고정운', 'EBS 에덴 아자르', '21UCL 비니시우스 주니어', '22TOTS 필 포든', 'VTR 프랑크 리베리', 'UP 페드로', '22TOTN 잭 그릴리시', '22TOTS 비니시우스 주니어', '21TOTN 네이마르 Jr.', 'LH 차범근', '21UCL 이반 페리시치', '21UCL 세르주 그나브리', '21UCL 루이스 디아스', '22TOTN 네이마르 Jr.', '22TOTN 필 포든'], ['RW', 'LH 차범근', '21UCL 세르주 그나브리', '21UCL 호드리구', 'UP 페드로', '19UCL 세르주 그나브리', '22TOTS 모하메드 살라', '21UCL 메이슨 마운트', 'EBS 가레스 베일', 'EBS 에덴 아자르', 'TKL 고정운', '21TOTS 모하메드 살라', '21UCL 리야드 마레즈', 'LOL 데얀 쿨루세브스키', '21KFA 이동준', '21TOTN 모하메드 살라', 'CAP 리오넬 메시'], ['CM', 'CAP 유상철', '2012KH 기성용', 'MC 미하엘 발락', '21UCL 아르투로 비달', '21KLB 이창민', 'TKL 유상철', '21UCL 티아고', '21UCL 케빈 더브라위너', 'LH 스티븐 제라드', 'EBS 스티븐 제라드', 'BTB 미하엘 발락', 'EBS 헤나투 산시스', 'MC 루드 굴리트', 'BOE21 P. 호이비에르', '22TOTN 마르코스 요렌테', '21UCL 토니 크로스'], ['CAM', '2012KH 지동원', '2012KH 박주영', 'LOL 이반 페리시치', '21UCL 세르주 그나브리', 'LH 차범근', 'TKL 고정운', '21UCL 사디오 마네', '21UCL 케빈 더브라위너', 'BOE21 카림 벤제마', '22TOTN 토마스 뮐러', '21UCL 메이슨 마운트', '21UCL 이반 페리시치', 'LN 루드 굴리트', 'MC 루드 굴리트', 'EBS 루드 굴리트', 'UP 페드로'], ['CDM', 'MC 미하엘 발락', 'CAP 유상철', '2012KH 기성용', '21UCL 아르투로 비달', '21KLB 이창민', 'MC 마이클 에시앙', 'TKL 유상철', '22TOTN 레온 고레츠카', 'FA 미하엘 발락', '22TOTN 마르코스 요렌테', '21UCL 데이비드 알라바', '21UCL 레온 고레츠카', 'BTB 미하엘 발락', 'LH 스티븐 제라드', '21TOTS 마르코스 요렌테', '21UCL 로드리'], ['LM', 'TKL 고정운', '21UCL 사디오 마네', 'EBS 에덴 아자르', 'UP 페드로', 'VTR 프랑크 리베리', '21UCL 이반 페리시치', 'LH 차범근', '22TOTS 필 포든', '21KFA 이동준', 'LN 잔프랑코 졸라', 'LOL 이반 페리시치', '21UCL 메이슨 마운트', '21UCL 세르주 그나브리', '22TOTN 필 포든', 'BTB 페드로', 'LH 이반 페리시치'], ['RM', 'LH 차범근', '21UCL 세르주 그나브리', 'TKL 고정운', '19UCL 세르주 그나브리', '21KFA 이동준', '21UCL 메이슨 마운트', '21UCL 호드리구', 'EBS 에덴 아자르', 'CFA 조 콜', 'UP 페드로', '21UCL 사디오 마네', 'MC 카카', 'BOE21 제르단 샤키리', 'LN 조 콜', 'VTR 프랑크 리베리', '21UCL 이반 페리시치'], ['CB', 'TKL 차두리', '21UCL 뱅자맹 파바르', '20UCL 안토니오 뤼디거', '21UCL 뤼카 에르난데스', '21UCL 에데르 밀리탕', 'BOE21 라파엘 바란', '22TOTN 안토니오 뤼디거', '21KLB 홍정호', '2012KH 윤석영', '21UCL 이브라히마 코나테', 'TKL 김민재', '21UCL 안토니오 뤼디거', '21UCL 다요 우파메카노', 'LOL 피카요 토모리', '22TOTN 크리스티안 로메로', 'BOE21 덴젤 둠프리스'], ['LB', '21UCL 벤 칠웰', '21KLB 이기제', '20UCL 알폰소 데이비스', '20UCL 벤 칠웰', 'LIVE 테오 에르난데스', 'TKL 홍철', '19UCL 알폰소 데이비스', '20UCL 데이비드 알라바', 'LH 데이비드 알라바', '21UCL 누누 멘데스', '21PLA 테오 에르난데스', '21UCL 페를랑 멘디', '21UCL 올렉산드르 진첸코', '19PLA 테오 에르난데스', 'TKL 하석주', 'LH 안드레아스 브레메'], ['RB', '19UCL 요주아 키미히', '20UCL 리스 제임스', 'TKL 김태환', '21UCL 아슈라프 하키미', '21KLB 강상우', '20UCL 카르바할', '21UCL 리스 제임스', 'BOE21 리스 제임스', '21UCL 카일 워커', '20UCL T. 알렉산더-아놀드', 'LIVE 아슈라프 하키미', '20KLB 김태환', '21KL 김태환', '21UCL 카르바할', 'LH 안드레아스 브레메', '21UCL 디오구 달로'], ['LWB', '21UCL 벤 칠웰', '21KLB 이기제', '21UCL K. 치미카스', '20UCL 벤 칠웰', '20UCL 알폰소 데이비스', '21UCL 페를랑 멘디', '21UCL 누누 멘데스', 'TKL 홍철', '19UCL 앤드루 로버트슨', 'TKL 하석주', 'LH 데이비드 알라바', 'LH 안드레아스 브레메', '21UCL 앤드루 로버트슨', '21UCL 올렉산드르 진첸코', 'LIVE 테오 에르난데스', '19NG 레길론'], ['RWB', '21UCL 아슈라프 하키미', '19UCL 요주아 키미히', '20UCL 리스 제임스', '21UCL 리스 제임스', 'TKL 김태환', '21KLB 강상우', '20UCL T. 알렉산더-아놀드', '21UCL 카일 워커', '21UCL 카르바할', '21UCL T. 알렉산더-아놀드', '20UCL 카르바할', 'LH 안드레아스 브레메', '20NG 에메르송', 'BOE21 리스 제임스', '20UCL 루카스 바스케스', '21UCL 후안 콰드라도'], ['GK', 'LIVE 티보 쿠르투아', '2012KH 이범영', 'LIVE 마누엘 노이어', '20UCL 티보 쿠르투아', 'NHD 에드윈 반데르사르', 'LIVE 잔루이지 돈나룸마', '21UCL 슈벤 울라이히', 'LH 티보 쿠르투아', 'TB 닉 포프', '21UCL 에우통 레이치', '22KL 양한빈', 'EBS 보이치에흐 슈체스니', 'TC 조 하트', 'LIVE 닉 포프', 'TB 티보 쿠르투아', 'LIVE 사미르 한다노비치']]

# %%
driver.quit()

# %% [markdown]
# # 데이터 시각화
#
# - 선수의 포지션,이름,클래스를 데이터프레임으로 시각화한다. 포지션은 선수 카드에 주어진 포지션이 아니라 유저들이 사용한 포지션을 따른다.
#
#    - ex) TKL 차두리의 원래 포지션은 RB이지만, 유저들은 CB으로 주로 사용하므로 TKL 차두리는 CB로 분류
#
# - 이후 csv 파일로 데이터프레임을 저장 후, 자동 스쿼드 제작에 활용한다.

# %%
players_dataset = []
columns = ['포지션','이름','클래스']
best_player = best_players[0] # 굳이 0 아니어도 됨, 포지션별 16명이므로 하나 정해두고
for i in range(len(best_players)):
    for k in range(len(best_player)-1):
        players_dataset.append([best_players[i][0],best_players[i][k+1].split(' ',1)[1],best_players[i][k+1].split(' ',1)[0]])
        
players_df = pd.DataFrame(players_dataset,columns=columns)
players_df # 시각화 완료
# Out:
#     포지션          이름     클래스
# 0    ST         박주영  2012KH
# 1    ST   R. 레반도프스키  22TOTY
# 2    ST  크리스티아누 호날두  22TOTS
# 3    ST  크리스티아누 호날두  21TOTY
# 4    ST        호나우두      MC
# ..   ..         ...     ...
# 235  GK  보이치에흐 슈체스니     EBS
# 236  GK        조 하트      TC
# 237  GK        닉 포프    LIVE
# 238  GK     티보 쿠르투아      TB
# 239  GK   사미르 한다노비치    LIVE
#
# [240 rows x 3 columns]

# %%
x = players_df[players_df['포지션']=='ST'] # 포지션이 ST인 선수들의 정보가 잘 나왔음을 확인
x
# Out:
#    포지션          이름     클래스
# 0   ST         박주영  2012KH
# 1   ST   R. 레반도프스키  22TOTY
# 2   ST  크리스티아누 호날두  22TOTS
# 3   ST  크리스티아누 호날두  21TOTY
# 4   ST        호나우두      MC
# 5   ST   R. 레반도프스키  21TOTY
# 6   ST         손흥민  22TOTY
# 7   ST         차범근      LN
# 8   ST         지동원  2012KH
# 9   ST       해리 케인  22TOTS
# 10  ST  크리스티아누 호날두      MC
# 11  ST      사뮈엘 에토      FA
# 12  ST    안드리 셰우첸코      LN
# 13  ST      사디오 마네   21UCL
# 14  ST   R. 레반도프스키  22TOTS
# 15  ST     카이 하베르츠   21UCL

# %%
players_df.to_csv("./players_data/players_data_221011.csv",index=False,encoding='cp949') # csv 파일 저장, 10일 11일 데일리차트 기준

# %% [markdown]
# **피파온라인4 데이터 분석**
#
# - 나의 공식경기 시간대별 승률 분석
# - 상위 랭커 분석

# %% [markdown]
# **Import Library**

# %%
import json # Json Object Array 이용
import requests # 호출 위함
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pickle
import datetime as dt
from tqdm.notebook import tqdm
from IPython.display import Image # 주피터 노트북에 이미지 삽입

# 폰트 설정
mpl.rc('font', family='New Gulim')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %matplotlib inline

pd.set_option('max_columns', 100) # To see 50 columns
pd.set_option('max_rows', 100) # To see 100 rows

# %% [markdown]
# [피파온라인 이용가이드] (https://developers.nexon.com/fifaonline4/guides#slink5)

# %%
# 이용 가이드
Image('C:/FIFA4/images/이용 가이드.png')

# %% [markdown]
# - Json 패키지 공부 필요
# - requests 패키지 공부 필요

# %%
# 넥슨 개발자센터에서 발급받은 나의 키
api_key = 'my_api_key'

# %% [markdown]
# ## 유저 정보 조회
#
# - 유저 고유 식별자로 유저 정보 조회

# %%
user_params = {'nickname' : 'HOJJIMIN'}
headers = {'Authorization' : api_key} # 조회시, headers 값 입력 필수 !
user_info_url = requests.get('https://api.nexon.co.kr/fifaonline4/v1.0/users?', \
                             params = user_params, headers = headers)
user_parsed_data = user_info_url.json()
user_info_data = pd.DataFrame(user_parsed_data, index = [0])

# %%
user_info_data

# %%
# 내 아이디 조회
headers = {'Authorization' : api_key} # 조회시, headers 값 입력 필수 !
HOJJIMIN_url = requests.get('https://api.nexon.co.kr/fifaonline4/v1.0/users/api_key', headers = headers) # 내 피파온라인 4 아이디

# %%
HOJJIMIN_parsed_data = HOJJIMIN_url.json()
print('My Information : ',HOJJIMIN_parsed_data)
HOJJIMIN = pd.DataFrame(HOJJIMIN_parsed_data, index = [0]) # Index 값 지정해줘야 데이터프레임 형태로 활용 가능
HOJJIMIN

# %%
HOJJIMIN_accessId = 'myaccessId' # API 조회 하기위한 나의 고유 Id 키 값
HOJJIMIN_accessId

# %% [markdown]
# ## 역대 최고 등급 조회
# - 유저 고유 식별자로 유저별 역대 최고 등급과 달성일자 조회

# %%
# 나의 최고 등급 조회
grade_url = requests.get('https://api.nexon.co.kr/fifaonline4/v1.0/users/HOJJIMIN_accessId/maxdivision', headers = headers)
grade_parsed_data = grade_url.json()
print('parsed_data : ', grade_parsed_data) # 실제 피파온라인4 개발자 센터에서 Test 했을 때, 2개의 값 존재
grade_data = pd.DataFrame(grade_parsed_data, index = [i for i in range(len(grade_parsed_data))]) # index 설정
grade_data
# Out:
# parsed_data :  [{'matchType': 50, 'division': 2100, 'achievementDate': '2020-10-01T11:55:24'}, {'matchType': 52, 'division': 2400, 'achievementDate': '2020-10-03T17:17:41'}]
#    matchType  division      achievementDate
# 0         50      2100  2020-10-01T11:55:24
# 1         52      2400  2020-10-03T17:17:41

# %%
# 최고 등급 조회 데이터의 'achievementDate' 변수를 '날짜', '시간' 변수로 분리
for i in tqdm(range(len(grade_data))):
    grade_data['Date'] = grade_data['achievementDate'].str.split('T')[i][0]
    grade_data['Time'] = grade_data['achievementDate'].str.split('T')[i][1]

grade_data = grade_data.drop(['achievementDate'], axis = 1)
grade_data # 분리 완료
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
#    matchType  division        Date      Time
# 0         50      2100  2020-10-03  17:17:41
# 1         52      2400  2020-10-03  17:17:41

# %% [markdown]
# - division (등급)과 matchType을 좀 더 보기 편하게 데이터 전처리를 진행할 필요 존재

# %% [markdown]
# ## 매치 종류

# %%
# 매치 종류 메타데이터 조회
match_url = requests.get('https://static.api.nexon.co.kr/fifaonline4/latest/matchtype.json') # 메타정보 -> 매치 종류 메타데이터 조회의 API 정보의 Request 값    
print(match_url) # <Response [200]> 호출 성공
match_parsed_data = match_url.json() # json 요청 및 파싱
match_type = pd.DataFrame(match_parsed_data)
match_type
# Out:
# <Response [200]>
#    matchtype      desc
# 0         30     리그 친선
# 1         40  클래식 1on1
# 2         50      공식경기
# 3         52      감독모드
# 4         60     공식 친선
# 5        204     볼타 친선
# 6        214     볼타 공식
# 7        224   볼타 AI대전
# 8        234    볼타 커스텀

# %%
# grade_data의 matchType 합치기 위한 전처리
match_type = match_type.rename(columns={'matchtype' : 'matchType'}) # 변수명 변경
match_type
# Out:
#    matchType      desc
# 0         30     리그 친선
# 1         40  클래식 1on1
# 2         50      공식경기
# 3         52      감독모드
# 4         60     공식 친선
# 5        204     볼타 친선
# 6        214     볼타 공식
# 7        224   볼타 AI대전
# 8        234    볼타 커스텀

# %% [markdown]
# ### 등급 & 매치 종류 데이터 합치기

# %%
# matchType 합치기 완료
grade_data = grade_data.merge(match_type, how = 'left', on = 'matchType')
grade_data = grade_data.rename(columns = {'desc' : 'Type'})
grade_data
# Out:
#    matchType  division        Date      Time  Type
# 0         50      2100  2020-10-03  17:17:41  공식경기
# 1         52      2400  2020-10-03  17:17:41  감독모드

# %%
# 피파온라인 등급 정보 데이터
division_url = requests.get('https://static.api.nexon.co.kr/fifaonline4/latest/division.json')
division_parsed_data = division_url.json()
print('division JSON : ', division_parsed_data)
division_data = pd.DataFrame(division_parsed_data)
division_data
# Out:
# division JSON :  [{'divisionId': 800, 'divisionName': '슈퍼챔피언스'}, {'divisionId': 900, 'divisionName': '챔피언스'}, {'divisionId': 1000, 'divisionName': '슈퍼챌린지'}, {'divisionId': 1100, 'divisionName': '챌린지1'}, {'divisionId': 1200, 'divisionName': '챌린지2'}, {'divisionId': 1300, 'divisionName': '챌린지3'}, {'divisionId': 2000, 'divisionName': '월드클래스1'}, {'divisionId': 2100, 'divisionName': '월드클래스2'}, {'divisionId': 2200, 'divisionName': '월드클래스3'}, {'divisionId': 2300, 'divisionName': '프로1'}, {'divisionId': 2400, 'divisionName': '프로2'}, {'divisionId': 2500, 'divisionName': '프로3'}, {'divisionId': 2600, 'divisionName': '세미프로1'}, {'divisionId': 2700, 'divisionName': '세미프로2'}, {'divisionId': 2800, 'divisionName': '세미프로3'}, {'divisionId': 2900, 'divisionName': '유망주1'}, {'divisionId': 3000, 'divisionName': '유망주2'}, {'divisionId': 3100, 'divisionName': '유망주3'}]
#     divisionId divisionName
# 0          800       슈퍼챔피언스
# 1          900         챔피언스
# 2         1000        슈퍼챌린지
# 3         1100         챌린지1
# 4         1200         챌린지2
# 5         1300         챌린지3
# 6         2000       월드클래스1
# 7         2100       월드클래스2
# 8         2200       월드클래스3
# 9         2300          프로1
# 10        2400          프로2
# 11        2500          프로3
# 12        2600        세미프로1
# 13        2700        세미프로2
# 14        2800        세미프로3
# 15        2900         유망주1
# 16        3000         유망주2
# 17        3100         유망주3

# %% [markdown]
# - 슈퍼챔피언스 ~ 유망주3까지의 등급이 존재
#
# - 슈퍼챔피언스가 피파온라인4 내에서 가장 높은 등급이다.

# %%
# division_data 데이터 전처리
division_data = division_data.rename(columns = {'divisionId' : 'division'})
division_data
# Out:
#     division divisionName
# 0        800       슈퍼챔피언스
# 1        900         챔피언스
# 2       1000        슈퍼챌린지
# 3       1100         챌린지1
# 4       1200         챌린지2
# 5       1300         챌린지3
# 6       2000       월드클래스1
# 7       2100       월드클래스2
# 8       2200       월드클래스3
# 9       2300          프로1
# 10      2400          프로2
# 11      2500          프로3
# 12      2600        세미프로1
# 13      2700        세미프로2
# 14      2800        세미프로3
# 15      2900         유망주1
# 16      3000         유망주2
# 17      3100         유망주3

# %%
# 데이터 합치기
grade_data = grade_data.merge(division_data, how = 'left', on = 'division')
grade_data # 정상적으로 합쳐진 것을 볼 수 있다.
# Out:
#    matchType  division        Date      Time  Type divisionName
# 0         50      2100  2020-10-03  17:17:41  공식경기       월드클래스2
# 1         52      2400  2020-10-03  17:17:41  감독모드          프로2

# %% [markdown]
# - 나의 최근 공식경기 시즌 최고 등급은 월드클래스2이다.
#
# - 나의 최근 감독모드 시즌 최고 등급은 프로2이다.

# %% [markdown]
# ## 매치 기록 조회
# - 유저 고유 식별자와 매치 종류로 유저의 매치 종류별 기록 조회
# - 최대 100건의 매치 조회가 가능하다.

# %%
headers = {'Authorization' : api_key} 
match_params = {'matchtype' : 50, 'offset' : 0, 'limit' : 100}
match_record_url = requests.get(f'https://api.nexon.co.kr/fifaonline4/v1.0/users/{HOJJIMIN_accessId}/matches?',\
                                params=match_params, headers = headers)
match_record_parsed_data = match_record_url.json()
print(match_record_parsed_data) # 총 100건의 매치 조회

# %%
type(match_record_parsed_data) # list 형태
# Out:
# list

# %% [markdown]
# ## 매치 상세 기록 조회
#
# - 위에서 얻은 매치 고유 식별자를 활용해 매치의 상세 정보를 조회
# - 매치 시점, 매치 종류와 매치에 참여한 유저의 상세한 매치 통계 반환

# %% [markdown]
# ### Match Data Loading

# %%
# 매치 상세 기록 조회 데이터 부르기
match_HOJJIMIN = pd.DataFrame()
for idx, match in tqdm(enumerate(match_record_parsed_data)):
    matchid = match_record_parsed_data[idx]
    match_detail_url = requests.get(f'https://api.nexon.co.kr/fifaonline4/v1.0/matches/{matchid}', headers = headers)
    match_detail_parsed_data = match_detail_url.json()
    temp = pd.DataFrame(match_detail_parsed_data)
    match_HOJJIMIN = pd.concat([match_HOJJIMIN, temp], axis = 0)
    
match_HOJJIMIN # 매치 상세 기록 데이터

# %% [markdown]
# #### Match Information
# - accessId : 유저 고유 식별자 (String)
# - nickname : 유저 닉네임 (String)
# - matchDetail : 매치 결과 상세 정보 (MatchDetailDTO)
# - shoot : 슈팅 정보 (ShootDTO)
# - shootDetail : 슈팅 별 상세정보 리스트 (Array)
# - pass : 패스 정보 (PassDTO)
# - defence : 수비 정보 (DefenceDTO)
# - player : 경기 사용 선수 정보 (Array)

# %% [markdown]
# - match_HOJJIMIN 데이터 셋을 살펴보면 인덱스가 (0,1)로 묶여진 것을 확인할 수 있다.
# - 이는 한 경기 내에서 2명의 유저를 의미한다.
# - 100경기를 각각 인덱스로 주어 변경한다.

# %% [markdown]
# ### Match Data Preprocessing

# %%
# 인덱스 변경
plus_index = list()
for i in range(0, 100):
    temp1 = i
    temp2 = i
    plus_index.append(temp1)
    plus_index.append(temp2)

len(plus_index)
# Out:
# 200

# %%
match_HOJJIMIN['change_index'] = plus_index
match_HOJJIMIN.head(3)

# %%
match_HOJJIMIN = match_HOJJIMIN.set_index('change_index', drop=True) # 인덱스 변경
match_HOJJIMIN

# %% [markdown]
# match_HOJJIMIN 데이터 내에 4가지 변수가 존재하지만 각 변수 내에서 값들은 매우 복잡한 형태로 되어있다.
# 전처리를 통해 변수 별 데이터를 따로 생성해 줄 필요가 있다.

# %%
# 첫 번째 데이터를 통해 어떤 형식으로 이루어져 있는가 확인해보자
matchid = match_record_parsed_data[0]
match_detail_url = requests.get(f'https://api.nexon.co.kr/fifaonline4/v1.0/matches/{matchid}', headers = headers)
match_detail_parsed_data = match_detail_url.json()
match_detail_parsed_data # 해당 데이터의 형태

# %% [markdown]
# matchId, matchDate, matchType, matchInfo 4개의 key 값이 존재한다.
#
# matchInfo 내에 리스트 형태로 accessId, nickname, matchDetail, shoot, shootDetail, pass, defence, player 8개의 변수가 존재한다.
#
# accessId, nickname 변수를 제외한 나머지 변수의 값 들은 딕셔너리 형태의 값을 띈다.
#
# 이것을 전처리 해야만 가독성 있는 데이터 프레임이 생성될 듯 하다.

# %%
match_info_data = pd.DataFrame()
match_detail_data = pd.DataFrame()
match_shoot_data = pd.DataFrame()
match_pass_data = pd.DataFrame()
match_defence_data = pd.DataFrame()

# %%
pd.DataFrame(match_detail_parsed_data['matchInfo'])

# %% [markdown]
# player 변수와 shootDetail은 어느정도 분석이 진행된 후 마저 분석을 진행하도록 해보겠다.

# %%
# DTO 정보 리스트 형태로 만들기
accessId_list = [m.get('accessId') for m in match_HOJJIMIN['matchInfo']]
nickname_list = [m.get('nickname') for m in match_HOJJIMIN['matchInfo']]
matchDetail_list = [m.get('matchDetail') for m in match_HOJJIMIN['matchInfo']]
shootDetail_list = [m.get('shoot') for m in match_HOJJIMIN['matchInfo']]
passDetail_list = [m.get('pass') for m in match_HOJJIMIN['matchInfo']]
defenceDetail_list = [m.get('defence') for m in match_HOJJIMIN['matchInfo']]

print('accessInfo 리스트 갯수 : ', len(accessId_list))
print('nicknameInfo 리스트 갯수 : ', len(nickname_list))
print('matchInfo 리스트 갯수 : ', len(matchDetail_list))
print('shoot 리스트 갯수 : ', len(shootDetail_list))
print('pass 리스트 갯수 : ', len(passDetail_list))
print('defence 리스트 갯수 : ', len( defenceDetail_list))
# Out:
# accessInfo 리스트 갯수 :  200
# nicknameInfo 리스트 갯수 :  200
# matchInfo 리스트 갯수 :  200
# shoot 리스트 갯수 :  200
# pass 리스트 갯수 :  200
# defence 리스트 갯수 :  200

# %%
match_HOJJIMIN

# %%
match_info_data = match_HOJJIMIN.iloc[:, [0,1,2]].reset_index(drop = True)
accessId_data = pd.DataFrame(accessId_list)
nickname_data = pd.DataFrame(nickname_list)
match_detail_data = pd.DataFrame(matchDetail_list)
match_shoot_data = pd.DataFrame(shootDetail_list)
match_pass_data = pd.DataFrame(passDetail_list)
match_defence_data = pd.DataFrame(defenceDetail_list)

print('Shape of match_info_data : ', match_info_data.shape)
print('Shape of accessId_data : ', accessId_data.shape)
print('Shape of nickname_data : ', nickname_data.shape)
print('Shape of match_detail_data : ', match_detail_data.shape)
print('Shape of match_shoot_data : ', match_shoot_data.shape)
print('Shape of match_pass_data : ', match_pass_data.shape)
print('Shape of match_defence_data : ', match_defence_data.shape)
# Out:
# Shape of match_info_data :  (200, 3)
# Shape of accessId_data :  (200, 1)
# Shape of nickname_data :  (200, 1)
# Shape of match_detail_data :  (200, 14)
# Shape of match_shoot_data :  (200, 16)
# Shape of match_pass_data :  (200, 14)
# Shape of match_defence_data :  (200, 4)

# %%
accessId_data = accessId_data.rename(columns={0 : 'accessId'}) # 컬럼명 변경
accessId_data.head(3)

# %%
nickname_data.head(5)
# Out:
#           0
# 0  HOJJIMIN
# 1  Ballacks
# 2  HOJJIMIN
# 3   제주도산양상추
# 4      살살해주

# %%
nickname_data = nickname_data.rename(columns={0 : 'nickname'}) # 컬럼명 변경
nickname_data.head(3)
# Out:
#    nickname
# 0  HOJJIMIN
# 1  Ballacks
# 2  HOJJIMIN

# %%
match_detail_data.head(3)
# Out:
#    seasonId matchResult  matchEndType  systemPause  foul  injury  redCards  \
# 0    202014           승             0            0     2       0         0
# 1    202014           패             0            1     2       0         0
# 2    202014           승             0            0     0       1         0
#
#    yellowCards  dribble  cornerKick  possession  offsideCount  averageRating  \
# 0            0       92           0          53             0        4.20556
# 1            0       63           1          47             0        4.11667
# 2            0      139           3          52             0        4.12222
#
#   controller
# 0   keyboard
# 1   keyboard
# 2   keyboard

# %%
match_shoot_data.head(3)
# Out:
#    shootTotal  effectiveShootTotal  shootOutScore  goalTotal  \
# 0           3                    2              0          1
# 1           6                    3              0          0
# 2           6                    4              4          1
#
#    goalTotalDisplay  ownGoal  shootHeading  goalHeading  shootFreekick  \
# 0                 1        0             0            0              1
# 1                 0        0             1            0              0
# 2                 1        0             1            0              0
#
#    goalFreekick  shootInPenalty  goalInPenalty  shootOutPenalty  \
# 0             0               2              1                1
# 1             0               3              0                3
# 2             0               5              1                1
#
#    goalOutPenalty  shootPenaltyKick  goalPenaltyKick
# 0               0                 0                0
# 1               0                 0                0
# 2               0                 0                0

# %%
match_pass_data.head(3)
# Out:
#    passTry  passSuccess  shortPassTry  shortPassSuccess  longPassTry  \
# 0      110          100            84                79            8
# 1       87           81            66                65            7
# 2      150          139           116               111            9
#
#    longPassSuccess  bouncingLobPassTry  bouncingLobPassSuccess  \
# 0                6                   0                       0
# 1                4                   0                       0
# 2                7                   0                       0
#
#    drivenGroundPassTry  drivenGroundPassSuccess  throughPassTry  \
# 0                    0                        0              12
# 1                    1                        1              12
# 2                    0                        0              23
#
#    throughPassSuccess  lobbedThroughPassTry  lobbedThroughPassSuccess
# 0                  12                     4                         3
# 1                  11                     1                         0
# 2                  21                     0                         0

# %%
match_defence_data.head(3)
# Out:
#    blockTry  blockSuccess  tackleTry  tackleSuccess
# 0         6             2          8              7
# 1         5             0         14              8
# 2        14             2          4              3

# %%
HOJJIMIN = pd.concat([match_info_data, accessId_data, nickname_data, match_detail_data, match_shoot_data, match_pass_data, match_defence_data], axis = 1)
HOJJIMIN.shape
# Out:
# (200, 53)

# %% [markdown]
# #### Pickle

# %%
with open('C:/FIFA4/pickles/HOJJIMIN.pkl', 'wb') as f: # 완성된 데이터프레임 pickle 형태로 저장
    pickle.dump(HOJJIMIN, f)

# %% [markdown]
# - MatchInfoDTO 중 shootDetail, player 변수를 제외한 나머지 변수들을 모두 추출하여 100경기 데이터 프레임을 만들었다.

# %%
with open('C:/FIFA4/pickles/HOJJIMIN.pkl', 'rb') as f: # pickle 데이터 부르기
    HOJJIMIN = pickle.load(f)

# %% [markdown]
# - 승리한 시간, 승리했을 때의 슈팅 횟수 등등 시각화 해보기

# %%
HOJJIMIN.to_csv('C:/FIFA4/Data/HOJJIMIN.csv', encoding = 'UTF-8', index = False)

# %%
HOJJIMIN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   matchId                   200 non-null    object
#  1   matchDate                 200 non-null    object
#  2   matchType                 200 non-null    int64
#  3   accessId                  200 non-null    object
#  4   nickname                  200 non-null    object
#  5   seasonId                  200 non-null    int64
#  6   matchResult               200 non-null    object
#  7   matchEndType              200 non-null    int64
#  8   systemPause               200 non-null    int64
#  9   foul                      200 non-null    int64
#  10  injury                    200 non-null    int64
#  11  redCards                  200 non-null    int64
#  12  yellowCards               200 non-null    int64
#  13  dribble                   200 non-null    int64
#  14  cornerKick                200 non-null    int64
#  15  possession                200 non-null    int64
#  16  offsideCount              200 non-null    int64
#  17  averageRating             200 non-null    float64
#  18  controller                200 non-null    object
#  19  shootTotal                200 non-null    int64
#  20  effectiveShootTotal       200 non-null    int64
#  21  shootOutScore             200 non-null    int64
#  22  goalTotal                 200 non-null    int64
#  23  goalTotalDisplay          200 non-null    int64
#  24  ownGoal                   200 non-null    int64
#  25  shootHeading              200 non-null    int64
#  26  goalHeading               200 non-null    int64
#  27  shootFreekick             200 non-null    int64
#  28  goalFreekick              200 non-null    int64
#  29  shootInPenalty            200 non-null    int64
#  30  goalInPenalty             200 non-null    int64
#  31  shootOutPenalty           200 non-null    int64
#  32  goalOutPenalty            200 non-null    int64
#  33  shootPenaltyKick          200 non-null    int64
#  34  goalPenaltyKick           200 non-null    int64
#  35  passTry                   200 non-null    int64
#  36  passSuccess               200 non-null    int64
#  37  shortPassTry              200 non-null    int64
#  38  shortPassSuccess          200 non-null    int64
#  39  longPassTry               200 non-null    int64
#  40  longPassSuccess           200 non-null    int64
#  41  bouncingLobPassTry        200 non-null    int64
#  42  bouncingLobPassSuccess    200 non-null    int64
#  43  drivenGroundPassTry       200 non-null    int64
#  44  drivenGroundPassSuccess   200 non-null    int64
#  45  throughPassTry            200 non-null    int64
#  46  throughPassSuccess        200 non-null    int64
#  47  lobbedThroughPassTry      200 non-null    int64
#  48  lobbedThroughPassSuccess  200 non-null    int64
#  49  blockTry                  200 non-null    int64
#  50  blockSuccess              200 non-null    int64
#  51  tackleTry                 200 non-null    int64
#  52  tackleSuccess             200 non-null    int64
# dtypes: float64(1), int64(46), object(6)
# memory usage: 82.9+ KB
